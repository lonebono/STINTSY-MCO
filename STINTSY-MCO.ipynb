# %% [markdown]
# # STINTSY MAJOR COURSE OUTPUT
#
# In this notebook, we will create our `three supervised machine learning models` on the Organ Retrieval and Collection of Health Information for Donation (ORCHID) dataset. Descriptions and downloadable files of the data are found in the link below.
#
# **LINK: https://physionet.org/content/orchid/2.1.1/**
#
#
# Dependencies and instructions to run the notebook to follow.
