# %% [markdown]
# # STINTSY MAJOR COURSE OUTPUT
#
# In this notebook, we will create our `three supervised machine learning models` on the Organ Retrieval and Collection of Health Information for Donation (ORCHID) dataset. The objective is to be able to predict the transplantability of a donor heart (Binary: Yes/No) based on donor demographics, cause of death, and longitudinal clinical data (Chemistry, CBC, and ABG events). Descriptions and downloadable files of the data are found in the link below.
#
# **LINK: https://physionet.org/content/orchid/2.1.1/**
#
#
# Dependencies and instructions to run the notebook to follow.

# %% [markdown]
# # Import Libraries

# %% [markdown]
# # Data Cleaning
#
# ### Cohort Selection
# ### Data Cleaning & Imputation
# ### Target Labeling Definitions

# %% [markdown]
# # Exploratory Data Analysis
#
# ### Feature distributions
# ### Missing data patterns
# ### Correlation analysis
# ### Target vs feature analysis (IMPORTANT?)

# %% [markdown]
# # Data Pre-processing
#
# ### Feature Engineering
# ### Scaling, Encoding, & Dimensionality Reduction

# %% [markdown]
# # Model Selection, Training, Analysis, & Tuning

# %% [markdown]
# ### Classical Model 1

# %% [markdown]
# ### Classical Model 2

# %% [markdown]
# ### Neural Network Model

# %% [markdown]
# # Model Evaluation
